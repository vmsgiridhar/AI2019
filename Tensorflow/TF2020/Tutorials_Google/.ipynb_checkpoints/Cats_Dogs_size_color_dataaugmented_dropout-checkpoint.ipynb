# %% [markdown]
# ![Syschith](syschith.png)

# %% [markdown]
# Copyright 2019 The TensorFlow Authors.

# %% [markdown]
# ### Dogs vs Cats Image Classification - Overfitting

# %% [markdown]
# * Concepts we learn in this tutorial
# > Building pipelines with image data being loaded from hard disk using tf.keras.preprocessing.image.ImageDataGenerator, Overfitting - How to identify and solve it

# %% [markdown]
# ### Importing libraries

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %% [markdown]
# ### Data Loading

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'

# %%
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)

# %%
zip_dir_base = os.path.dirname(zip_dir)
# !find $zip_dir_base -type d -print
# Out:
# /Users/z003z7n/.keras/datasets
# /Users/z003z7n/.keras/datasets/cats_and_dogs_filtered
# /Users/z003z7n/.keras/datasets/cats_and_dogs_filtered/train
# /Users/z003z7n/.keras/datasets/cats_and_dogs_filtered/train/dogs
# /Users/z003z7n/.keras/datasets/cats_and_dogs_filtered/train/cats
# /Users/z003z7n/.keras/datasets/cats_and_dogs_filtered/validation
# /Users/z003z7n/.keras/datasets/cats_and_dogs_filtered/validation/dogs
# /Users/z003z7n/.keras/datasets/cats_and_dogs_filtered/validation/cats
# /Users/z003z7n/.keras/datasets/fashion-mnist

# %%
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')  # directory with our training cat pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')  # directory with our training dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')  # directory with our validation cat pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')  # directory with our validation dog pictures

# %% [markdown]
# ### Understanding the data

# %%
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))
num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

# %%
total_train = num_cats_tr + num_dogs_tr
total_validation = num_cats_val + num_dogs_val

# %%
total_train
# Out:
# 2000

# %%
total_validation
# Out:
# 1000

# %%
print('total training cat images:', num_cats_tr)
print('total training dog images:', num_dogs_tr)

print('total validation cat images:', num_cats_val)
print('total validation dog images:', num_dogs_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_validation)
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# --
# Total training images: 2000
# Total validation images: 1000

# %%
num_cats_tr
# Out:
# 1000

# %% [markdown]
# ### Setting model parameters

# %%
BATCH_SIZE = 100 # Number of training examples to process before updating our models variables
IMG_SHAPE = 150 # Our training data consists of images with width of 150 pixels and height of 150 pixels

# %% [markdown]
# ## Data Augmentation -- Method 1 of reducting the overfitting

# %% [markdown]
# # We apply data augmentation when training set is having very
# # few varieties of images. We create more training data in this
# # step
#
# Overfitting often occurs when we have a small number of training examples. One way to fix this problem is to augment our dataset so that it has sufficient number and variety of training examples. Data augmentation takes the approach of generating more training data from existing training samples, by augmenting the samples through random transformations that yield believable-looking images. The goal is that at training time, your model will never see the exact same picture twice. This exposes the model to more aspects of the data, allowing it to generalize better.
#
# In tf.keras we can implement this using the same ImageDataGenerator class we used before. We can simply pass different transformations we would want to our dataset as a form of arguments and it will take care of applying it to the dataset during our training process.
#
# To start off, let's define a function that can display an image, so we can see the type of augmentation that has been performed. Then, we'll look at specific augmentations that we'll use during training.

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Flipping the image horizontally
#
# We can begin by randomly applying horizontal flip augmentation to our dataset and seeing how individual images will look after the transformation. This is achieved by passing horizontal_flip=True as an argument to the ImageDataGenerator class.

# %%
image_gen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)

train_data_gen = image_gen.flow_from_directory(batch_size=BATCH_SIZE,
                                               directory=train_dir,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE,IMG_SHAPE))
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# To see the transformation in action, let's take one sample image from our training set and repeat it five times. The augmentation will be randomly applied (or not) to each repetition.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ### Rotating the image
# The rotation augmentation will randomly rotate the image up to a specified number of degrees. Here, we'll set it to 45.

# %%
image_gen = ImageDataGenerator(rescale=1./255, rotation_range=45)

train_data_gen = image_gen.flow_from_directory(batch_size=BATCH_SIZE,
                                               directory=train_dir,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# To see the transformation in action, let's once again take a sample image from our training set and repeat it. The augmentation will be randomly applied (or not) to each repetition.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ### Data preparation

# %% [markdown]
# Images must be formatted into appropriately pre-processed floating point tensors before being fed into the network. The steps involved in preparing these images are:
#
# Read images from the disk
# Decode contents of these images and convert it into proper grid format as per their RGB content
# Convert them into floating point tensors
# Rescale the tensors from values between 0 and 255 to values between 0 and 1, as neural networks prefer to deal with small input values.
# Fortunately, all these tasks can be done using the class tf.keras.preprocessing.image.ImageDataGenerator.
#
# We can set this up in a couple of lines of code.

# %%
train_image_generator = ImageDataGenerator(rescale = 1./255)
validation_image_generator = ImageDataGenerator(rescale = 1./255)

# %% [markdown]
# After defining our generators for training and validation images, flow_from_directory method will load images from the disk, apply rescaling, and resize them using single line of code.

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                           class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                              directory=validation_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                              class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# ### Visualizing Training Images

# %% [markdown]
# We can visualize our training images by getting a batch of images from the training generator, and then plotting a few of them using matplotlib.

# %%
sample_training_images, _ = next(train_data_gen)

# %% [markdown]
# The next function returns a batch from the dataset. One batch is a tuple of (many images, many labels). For right now, we're discarding the labels because we just want to look at the images.

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
plotImages(sample_training_images[:5])  # Plot images 0-4

# %% [markdown]
# ### Model Creation

# %% [markdown]
# Define the model
# The model consists of four convolution blocks with a max pool layer in each of them. Then we have a fully connected layer with 512 units, with a relu activation function. The model will output class probabilities for two classes — dogs and cats — using softmax.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2)
])

# %% [markdown]
# Compile the model
# As usual, we will use the adam optimizer. Since we output a softmax categorization, we'll use sparse_categorical_crossentropy as the loss function. We would also like to look at training and validation accuracy on each epoch as we train our network, so we are passing in the metrics argument.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model
#
# It's time we train our network.
#
# Since our batches are coming from a generator (ImageDataGenerator), we'll use fit_generator instead of fit.

# %%
EPOCHS = 100
history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))),
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(total_validation / float(BATCH_SIZE)))
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 27s 1s/step - loss: 0.7232 - accuracy: 0.5165 - val_loss: 0.6880 - val_accuracy: 0.6070
# Epoch 2/100
# 20/20 [==============================] - 28s 1s/step - loss: 0.6919 - accuracy: 0.5235 - val_loss: 0.6916 - val_accuracy: 0.5130
# Epoch 3/100
# 20/20 [==============================] - 55s 3s/step - loss: 0.6857 - accuracy: 0.5615 - val_loss: 0.6465 - val_accuracy: 0.6400
# Epoch 4/100
# 20/20 [==============================] - 38s 2s/step - loss: 0.6505 - accuracy: 0.6240 - val_loss: 0.6012 - val_accuracy: 0.6760
# Epoch 5/100
# 20/20 [==============================] - 35s 2s/step - loss: 0.6056 - accuracy: 0.6790 - val_loss: 0.5636 - val_accuracy: 0.7090
# Epoch 6/100
# 20/20 [==============================] - 39s 2s/step - loss: 0.5581 - accuracy: 0.7055 - val_loss: 0.5734 - val_accuracy: 0.7030
# Epoch 7/100
# 20/20 [==============================] - 41s 2s/step - loss: 0.5291 - accuracy: 0.7315 - val_loss: 0.5917 - val_accuracy: 0.6880
# Epoch 8/100
# 20/20 [==============================] - 34s 2s/step - loss: 0.5101 - accuracy: 0.7510 - val_loss: 0.5982 - val_accuracy: 0.6870
# Epoch 9/100
# 20/20 [==============================] - 36s 2s/step - loss: 0.4830 - accuracy: 0.7630 - val_loss: 0.5407 - val_accuracy: 0.7170
# Epoch 10/100
# 20/20 [==============================] - 37s 2s/step - loss: 0.4268 - accuracy: 0.8105 - val_loss: 0.6198 - val_accuracy: 0.6980
# Epoch 11/100
# 20/20 [==============================] - 35s 2s/step - loss: 0.3976 - accuracy: 0.8225 - val_loss: 0.5860 - val_accuracy: 0.7280
# Epoch 12/100
# 20/20 [==============================] - 37s 2s/step - loss: 0.3663 - accuracy: 0.8405 - val_loss: 0.5681 - val_accuracy: 0.7420
# Epoch 13/100
# 20/20 [==============================] - 38s 2s/step - loss: 0.3144 - accuracy: 0.8620 - val_loss: 0.5630 - val_accuracy: 0.7440
# Epoch 14/100
# 20/20 [==============================] - 37s 2s/step - loss: 0.2739 - accuracy: 0.8830 - val_loss: 0.5925 - val_accuracy: 0.7430
# Epoch 15/100
# 20/20 [==============================] - 36s 2s/step - loss: 0.2765 - accuracy: 0.8820 - val_loss: 0.6203 - val_accuracy: 0.7270
# Epoch 16/100
# 20/20 [==============================] - 36s 2s/step - loss: 0.2154 - accuracy: 0.9120 - val_loss: 0.6945 - val_accuracy: 0.7460
# Epoch 17/100
# 20/20 [==============================] - 36s 2s/step - loss: 0.1475 - accuracy: 0.9415 - val_loss: 0.6761 - val_accuracy: 0.7510
# Epoch 18/100
# 20/20 [==============================] - 37s 2s/step - loss: 0.1182 - accuracy: 0.9550 - val_loss: 0.7554 - val_accuracy: 0.7520
# Epoch 19/100
# 20/20 [==============================] - 37s 2s/step - loss: 0.1281 - accuracy: 0.9480 - val_loss: 0.7886 - val_accuracy: 0.7380
# Epoch 20/100
# 20/20 [==============================] - 34s 2s/step - loss: 0.0906 - accuracy: 0.9720 - val_loss: 0.8185 - val_accuracy: 0.7470
# Epoch 21/100
# 20/20 [==============================] - 36s 2s/step - loss: 0.0657 - accuracy: 0.9750 - val_loss: 1.0021 - val_accuracy: 0.7430
# Epoch 22/100
# 20/20 [==============================] - 35s 2s/step - loss: 0.0371 - accuracy: 0.9885 - val_loss: 0.9897 - val_accuracy: 0.7630
# Epoch 23/100
# 20/20 [==============================] - 36s 2s/step - loss: 0.0162 - accuracy: 0.9985 - val_loss: 1.1315 - val_accuracy: 0.7590
# Epoch 24/100
# 20/20 [==============================] - 34s 2s/step - loss: 0.0123 - accuracy: 0.9975 - val_loss: 1.2868 - val_accuracy: 0.7530
# Epoch 25/100
# 20/20 [==============================] - 35s 2s/step - loss: 0.0144 - accuracy: 0.9960 - val_loss: 1.1675 - val_accuracy: 0.7490
# Epoch 26/100
# 20/20 [==============================] - 37s 2s/step - loss: 0.0161 - accuracy: 0.9960 - val_loss: 1.2128 - val_accuracy: 0.7720
# Epoch 27/100
# 20/20 [==============================] - 33s 2s/step - loss: 0.0238 - accuracy: 0.9925 - val_loss: 1.1781 - val_accuracy: 0.7590
# Epoch 28/100
# 20/20 [==============================] - 36s 2s/step - loss: 0.0158 - accuracy: 0.9960 - val_loss: 1.1492 - val_accuracy: 0.7750
# Epoch 29/100
# 20/20 [==============================] - 37s 2s/step - loss: 0.0313 - accuracy: 0.9900 - val_loss: 1.3495 - val_accuracy: 0.7330
# Epoch 30/100
# 20/20 [==============================] - 35s 2s/step - loss: 0.0488 - accuracy: 0.9815 - val_loss: 1.1017 - val_accuracy: 0.7730
# Epoch 31/100
# 20/20 [==============================] - 34s 2s/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 1.1753 - val_accuracy: 0.7690
# Epoch 32/100
# 20/20 [==============================] - 36s 2s/step - loss: 0.0102 - accuracy: 0.9985 - val_loss: 1.2797 - val_accuracy: 0.7580
# Epoch 33/100
# 20/20 [==============================] - 37s 2s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.3087 - val_accuracy: 0.7700
# Epoch 34/100
# 20/20 [==============================] - 37s 2s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.3250 - val_accuracy: 0.7760
# Epoch 35/100
# 20/20 [==============================] - 37s 2s/step - loss: 5.4414e-04 - accuracy: 1.0000 - val_loss: 1.3649 - val_accuracy: 0.7750
# Epoch 36/100
# 20/20 [==============================] - 38s 2s/step - loss: 4.0146e-04 - accuracy: 1.0000 - val_loss: 1.3825 - val_accuracy: 0.7760
# Epoch 37/100
# 20/20 [==============================] - 40s 2s/step - loss: 3.1633e-04 - accuracy: 1.0000 - val_loss: 1.3955 - val_accuracy: 0.7770
# Epoch 38/100
# 20/20 [==============================] - 39s 2s/step - loss: 2.7140e-04 - accuracy: 1.0000 - val_loss: 1.4114 - val_accuracy: 0.7760
# Epoch 39/100
# 20/20 [==============================] - 35s 2s/step - loss: 2.3544e-04 - accuracy: 1.0000 - val_loss: 1.4257 - val_accuracy: 0.7750
# Epoch 40/100
# 20/20 [==============================] - 37s 2s/step - loss: 2.1285e-04 - accuracy: 1.0000 - val_loss: 1.4416 - val_accuracy: 0.7810
# Epoch 41/100
# 20/20 [==============================] - 36s 2s/step - loss: 1.9054e-04 - accuracy: 1.0000 - val_loss: 1.4527 - val_accuracy: 0.7780
# Epoch 42/100
# 20/20 [==============================] - 35s 2s/step - loss: 1.7337e-04 - accuracy: 1.0000 - val_loss: 1.4643 - val_accuracy: 0.7780
# Epoch 43/100
# 20/20 [==============================] - 34s 2s/step - loss: 1.5984e-04 - accuracy: 1.0000 - val_loss: 1.4731 - val_accuracy: 0.7780
# Epoch 44/100
# 20/20 [==============================] - 35s 2s/step - loss: 1.4703e-04 - accuracy: 1.0000 - val_loss: 1.4834 - val_accuracy: 0.7780
# Epoch 45/100
# 20/20 [==============================] - 35s 2s/step - loss: 1.3585e-04 - accuracy: 1.0000 - val_loss: 1.4943 - val_accuracy: 0.7780
# Epoch 46/100
# 20/20 [==============================] - 35s 2s/step - loss: 1.2729e-04 - accuracy: 1.0000 - val_loss: 1.5041 - val_accuracy: 0.7780
# Epoch 47/100
# 20/20 [==============================] - 35s 2s/step - loss: 1.1856e-04 - accuracy: 1.0000 - val_loss: 1.5120 - val_accuracy: 0.7820
# Epoch 48/100
# 20/20 [==============================] - 35s 2s/step - loss: 1.1104e-04 - accuracy: 1.0000 - val_loss: 1.5200 - val_accuracy: 0.7790
# Epoch 49/100
# 20/20 [==============================] - 36s 2s/step - loss: 1.0509e-04 - accuracy: 1.0000 - val_loss: 1.5286 - val_accuracy: 0.7810
# Epoch 50/100
# 20/20 [==============================] - 36s 2s/step - loss: 9.8924e-05 - accuracy: 1.0000 - val_loss: 1.5362 - val_accuracy: 0.7810
# Epoch 51/100
# 20/20 [==============================] - 36s 2s/step - loss: 9.2893e-05 - accuracy: 1.0000 - val_loss: 1.5437 - val_accuracy: 0.7830
# Epoch 52/100
# 20/20 [==============================] - 37s 2s/step - loss: 8.8081e-05 - accuracy: 1.0000 - val_loss: 1.5510 - val_accuracy: 0.7830
# Epoch 53/100
# 20/20 [==============================] - 46s 2s/step - loss: 8.3847e-05 - accuracy: 1.0000 - val_loss: 1.5585 - val_accuracy: 0.7840
# Epoch 54/100
# 20/20 [==============================] - 37s 2s/step - loss: 7.9275e-05 - accuracy: 1.0000 - val_loss: 1.5649 - val_accuracy: 0.7830
# Epoch 55/100
# 20/20 [==============================] - 33s 2s/step - loss: 7.5459e-05 - accuracy: 1.0000 - val_loss: 1.5713 - val_accuracy: 0.7850
# Epoch 56/100
# 20/20 [==============================] - 35s 2s/step - loss: 7.1849e-05 - accuracy: 1.0000 - val_loss: 1.5778 - val_accuracy: 0.7850
# Epoch 57/100
# 20/20 [==============================] - 36s 2s/step - loss: 6.8862e-05 - accuracy: 1.0000 - val_loss: 1.5848 - val_accuracy: 0.7830
# Epoch 58/100
# 20/20 [==============================] - 36s 2s/step - loss: 6.5742e-05 - accuracy: 1.0000 - val_loss: 1.5910 - val_accuracy: 0.7840
# Epoch 59/100
# 20/20 [==============================] - 37s 2s/step - loss: 6.2739e-05 - accuracy: 1.0000 - val_loss: 1.5972 - val_accuracy: 0.7830
# Epoch 60/100
# 20/20 [==============================] - 38s 2s/step - loss: 6.0199e-05 - accuracy: 1.0000 - val_loss: 1.6022 - val_accuracy: 0.7840
# Epoch 61/100
# 20/20 [==============================] - 41s 2s/step - loss: 5.7825e-05 - accuracy: 1.0000 - val_loss: 1.6080 - val_accuracy: 0.7840
# Epoch 62/100
# 20/20 [==============================] - 38s 2s/step - loss: 5.5535e-05 - accuracy: 1.0000 - val_loss: 1.6136 - val_accuracy: 0.7830
# Epoch 63/100
# 20/20 [==============================] - 36s 2s/step - loss: 5.3423e-05 - accuracy: 1.0000 - val_loss: 1.6199 - val_accuracy: 0.7840
# Epoch 64/100
# 20/20 [==============================] - 36s 2s/step - loss: 5.1402e-05 - accuracy: 1.0000 - val_loss: 1.6247 - val_accuracy: 0.7830
# Epoch 65/100
# 20/20 [==============================] - 36s 2s/step - loss: 4.9343e-05 - accuracy: 1.0000 - val_loss: 1.6298 - val_accuracy: 0.7840
# Epoch 66/100
# 20/20 [==============================] - 36s 2s/step - loss: 4.7561e-05 - accuracy: 1.0000 - val_loss: 1.6352 - val_accuracy: 0.7830
# Epoch 67/100
# 20/20 [==============================] - 36s 2s/step - loss: 4.5856e-05 - accuracy: 1.0000 - val_loss: 1.6399 - val_accuracy: 0.7840
# Epoch 68/100
# 20/20 [==============================] - 36s 2s/step - loss: 4.4365e-05 - accuracy: 1.0000 - val_loss: 1.6452 - val_accuracy: 0.7850
# Epoch 69/100
# 20/20 [==============================] - 37s 2s/step - loss: 4.2747e-05 - accuracy: 1.0000 - val_loss: 1.6498 - val_accuracy: 0.7840
# Epoch 70/100
# 20/20 [==============================] - 40s 2s/step - loss: 4.1346e-05 - accuracy: 1.0000 - val_loss: 1.6548 - val_accuracy: 0.7850
# Epoch 71/100
# 20/20 [==============================] - 51s 3s/step - loss: 3.9892e-05 - accuracy: 1.0000 - val_loss: 1.6586 - val_accuracy: 0.7850
# Epoch 72/100
# 20/20 [==============================] - 54s 3s/step - loss: 3.8543e-05 - accuracy: 1.0000 - val_loss: 1.6630 - val_accuracy: 0.7860
# Epoch 73/100
# 20/20 [==============================] - 49s 2s/step - loss: 3.7343e-05 - accuracy: 1.0000 - val_loss: 1.6683 - val_accuracy: 0.7850
# Epoch 74/100
# 20/20 [==============================] - 41s 2s/step - loss: 3.6254e-05 - accuracy: 1.0000 - val_loss: 1.6724 - val_accuracy: 0.7870
# Epoch 75/100
# 20/20 [==============================] - 44s 2s/step - loss: 3.5036e-05 - accuracy: 1.0000 - val_loss: 1.6769 - val_accuracy: 0.7860
# Epoch 76/100
# 20/20 [==============================] - 46s 2s/step - loss: 3.4027e-05 - accuracy: 1.0000 - val_loss: 1.6805 - val_accuracy: 0.7870
# Epoch 77/100
# 20/20 [==============================] - 40s 2s/step - loss: 3.2951e-05 - accuracy: 1.0000 - val_loss: 1.6856 - val_accuracy: 0.7870
# Epoch 78/100
# 20/20 [==============================] - 41s 2s/step - loss: 3.2020e-05 - accuracy: 1.0000 - val_loss: 1.6900 - val_accuracy: 0.7870
# Epoch 79/100
# 20/20 [==============================] - 43s 2s/step - loss: 3.1392e-05 - accuracy: 1.0000 - val_loss: 1.6935 - val_accuracy: 0.7860
# Epoch 80/100
# 20/20 [==============================] - 43s 2s/step - loss: 3.0092e-05 - accuracy: 1.0000 - val_loss: 1.6980 - val_accuracy: 0.7870
# Epoch 81/100
# 20/20 [==============================] - 43s 2s/step - loss: 2.9350e-05 - accuracy: 1.0000 - val_loss: 1.7020 - val_accuracy: 0.7870
# Epoch 82/100
# 20/20 [==============================] - 46s 2s/step - loss: 2.8461e-05 - accuracy: 1.0000 - val_loss: 1.7054 - val_accuracy: 0.7870
# Epoch 83/100
# 20/20 [==============================] - 47s 2s/step - loss: 2.7729e-05 - accuracy: 1.0000 - val_loss: 1.7093 - val_accuracy: 0.7870
# Epoch 84/100
# 20/20 [==============================] - 46s 2s/step - loss: 2.6982e-05 - accuracy: 1.0000 - val_loss: 1.7133 - val_accuracy: 0.7870
# Epoch 85/100
# 20/20 [==============================] - 44s 2s/step - loss: 2.6169e-05 - accuracy: 1.0000 - val_loss: 1.7166 - val_accuracy: 0.7870
# Epoch 86/100
# 20/20 [==============================] - 44s 2s/step - loss: 2.5491e-05 - accuracy: 1.0000 - val_loss: 1.7207 - val_accuracy: 0.7870
# Epoch 87/100
# 20/20 [==============================] - 45s 2s/step - loss: 2.4788e-05 - accuracy: 1.0000 - val_loss: 1.7248 - val_accuracy: 0.7870
# Epoch 88/100
# 20/20 [==============================] - 44s 2s/step - loss: 2.4156e-05 - accuracy: 1.0000 - val_loss: 1.7281 - val_accuracy: 0.7850
# Epoch 89/100
# 20/20 [==============================] - 45s 2s/step - loss: 2.3513e-05 - accuracy: 1.0000 - val_loss: 1.7324 - val_accuracy: 0.7870
# Epoch 90/100
# 20/20 [==============================] - 42s 2s/step - loss: 2.2913e-05 - accuracy: 1.0000 - val_loss: 1.7360 - val_accuracy: 0.7860
# Epoch 91/100
# 20/20 [==============================] - 43s 2s/step - loss: 2.2382e-05 - accuracy: 1.0000 - val_loss: 1.7394 - val_accuracy: 0.7860
# Epoch 92/100
# 20/20 [==============================] - 43s 2s/step - loss: 2.1794e-05 - accuracy: 1.0000 - val_loss: 1.7426 - val_accuracy: 0.7850
# Epoch 93/100
# 20/20 [==============================] - 42s 2s/step - loss: 2.1266e-05 - accuracy: 1.0000 - val_loss: 1.7463 - val_accuracy: 0.7840
# Epoch 94/100
# 20/20 [==============================] - 42s 2s/step - loss: 2.0740e-05 - accuracy: 1.0000 - val_loss: 1.7499 - val_accuracy: 0.7860
# Epoch 95/100
# 20/20 [==============================] - 42s 2s/step - loss: 2.0185e-05 - accuracy: 1.0000 - val_loss: 1.7534 - val_accuracy: 0.7840
# Epoch 96/100
# 20/20 [==============================] - 42s 2s/step - loss: 1.9742e-05 - accuracy: 1.0000 - val_loss: 1.7569 - val_accuracy: 0.7860
# Epoch 97/100
# 20/20 [==============================] - 43s 2s/step - loss: 1.9256e-05 - accuracy: 1.0000 - val_loss: 1.7598 - val_accuracy: 0.7840
# Epoch 98/100
# 20/20 [==============================] - 43s 2s/step - loss: 1.8775e-05 - accuracy: 1.0000 - val_loss: 1.7636 - val_accuracy: 0.7850
# Epoch 99/100
# 20/20 [==============================] - 43s 2s/step - loss: 1.8374e-05 - accuracy: 1.0000 - val_loss: 1.7673 - val_accuracy: 0.7860
# Epoch 100/100
# 20/20 [==============================] - 44s 2s/step - loss: 1.7916e-05 - accuracy: 1.0000 - val_loss: 1.7704 - val_accuracy: 0.7840

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./foo.png')
plt.show()

# %% [markdown]
# As we can see from the plots, training accuracy and validation accuracy are off by large margin and our model has achieved only around 70% accuracy on the validation set (depending on the number of epochs you trained for).
#
# This is a clear indication of overfitting. Once the training and validation curves start to diverge, our model has started to memorize the training data and is unable to perform well on the validation data.

# %% [markdown]
# Note:
#
# We have used 2 inputs in the last layer and used softmax to classify between dogs and cats.
#
# tf.keras.layers.Dense(2, activation='softmax')
#
# If we use the sigmoid based binary classification, we use the following layer
#
# tf.keras.layers.Dense(1, activation='sigmoid')
#
# In the above case, the loss parameter in the model.compile() should be 'binary_crossentropy' instead of 'saprse_categorical_crossentropy'

# %% [markdown]
# Solutions to the overfitting problems:
# 1. Image Augmentation - While training, we do zoom, rotate, invert of images so that the model will generalize well on test set when the image will get classified well regardless of the position of the object in the image.
#
# 2. Dropout: During training, in the neural network, some of the nerons get more weighted and biased. The other neurons do not take active role in the training and thus this causes overfitting. For this, we randomly stop some neurons during training, eventually upon all the epochs, each neuron gets off atleast once and thus the way in which the neurons processes the weights and biases will be balanced, thus avoiding the overfitting.
