# %% [markdown]
# ![Syschith](syschith.png)

# %% [markdown]
# Copyright 2019 The TensorFlow Authors.

# %% [markdown]
# * Task: To classify the images of flowers
# * Infrastructure we are going to use: tf.keras.Sequential
# * Loading of data will be done by tf.keras.prepocessing.image.ImageDataGenerator

# %% [markdown]
# ### Importing packages

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import shutil
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import glob
# os - to read files in the directories of file system
# keras - API for the NN
# numpy - to convert python list into numpy array and perform requried matrix operations.
# matplotlib - to plot model performance graphs and display images.
# shutil - high level operations on files and file collections.
# ImageDataGenerator - to work on the Augmenting the image data.

# %% [markdown]
# ### Data Loading

# %%
_URL = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

# %%
zip_file = tf.keras.utils.get_file(origin = _URL,
                                  fname = "flower_photos.tgz",
                                  extract = True)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 355s 2us/step

# %%
base_dir = os.path.join(os.path.dirname(zip_file), 'flower_photos')

# %%
base_dir
# Out:
# '/Users/z003z7n/.keras/datasets/flower_photos'

# %%
# classes (types of flowers in our dataset)
classes = ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
os.listdir(base_dir)
# Out:
# ['roses', 'sunflowers', 'daisy', 'dandelion', 'tulips', 'LICENSE.txt']

# %%
# We observe here above that we dont have training and testing sets. So, lets create them using the following code.

# %%
for cl in classes:
  img_path = os.path.join(base_dir, cl)
  images = glob.glob(img_path + '/*.jpg')
  print("{}: {} Images".format(cl, len(images)))
  train, val = images[:round(len(images)*0.8)], images[round(len(images)*0.8):]

  for t in train:
    if not os.path.exists(os.path.join(base_dir, 'train', cl)):
      os.makedirs(os.path.join(base_dir, 'train', cl))
    shutil.move(t, os.path.join(base_dir, 'train', cl))

  for v in val:
    if not os.path.exists(os.path.join(base_dir, 'val', cl)):
      os.makedirs(os.path.join(base_dir, 'val', cl))
    shutil.move(v, os.path.join(base_dir, 'val', cl))
# Out:
# daisy: 633 Images
# dandelion: 898 Images
# roses: 641 Images
# sunflowers: 699 Images
# tulips: 799 Images

# %%
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')

# %% [markdown]
# ### Data Augmentation
#
# Overfitting generally occurs when we have small number of training examples. One way to fix this problem is to augment our dataset so that it has sufficient number of training examples. Data augmentation takes the approach of generating more training data from existing training samples, by augmenting the samples via a number of random transformations that yield believable-looking images. The goal is that at training time, your model will never see the exact same picture twice. This helps expose the model to more aspects of the data and generalize better.
#
# In tf.keras we can implement this using the same ImageDataGenerator class we used before. We can simply pass different transformations we would want to our dataset as a form of arguments and it will take care of applying it to the dataset during our training process.

# %% [markdown]
# ### Experiment with Various Image Transformations
# In this section you will get some practice doing some basic image transformations. Before we begin making transformations let's define our batch_size and our image size. Remember that the input to our CNN are images of the same size. We therefore have to resize the images in our dataset to the same size.

# %%
BATCH_SIZE = 100 # Number of training examples to process before updating our models variables
IMG_SHAPE = 150 # Our training data consists of images with width of 150 pixels and height of 150 pixels

# %% [markdown]
# In the cell below, use ImageDataGenerator to create a transformation that rescales the images by 255 and then applies a random horizontal flip. Then use the .flow_from_directory method to apply the above transformation to the images in our training set. Make sure you indicate the batch size, the path to the directory of the training images, the target size for the images, and to shuffle the images.

# %%
image_gen = ImageDataGenerator(rescale=1./255, horizontal_flip = True)

train_data_gen = image_gen.flow_from_directory(batch_size=BATCH_SIZE,
                                               directory=train_dir,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 2935 images belonging to 5 classes.

# %% [markdown]
# Let's take 1 sample image from our training examples and repeat it 5 times so that the augmentation can be applied to the same image 5 times over randomly, to see the augmentation in action.

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()


augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ### Applying Random Rotation
#
# In the cell below, use ImageDataGenerator to create a transformation that rescales the images by 255 and then applies a random 45 degree rotation. Then use the .flow_from_directory method to apply the above transformation to the images in our training set. Make sure you indicate the batch size, the path to the directory of the training images, the target size for the images, and to shuffle the images.

# %%
image_gen = ImageDataGenerator(rescale=1./255, rotation_range = 45)

train_data_gen = image_gen.flow_from_directory(batch_size=BATCH_SIZE,
                                               directory=train_dir,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 2935 images belonging to 5 classes.

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()


augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ### Apply Random Zoom
# In the cell below, use ImageDataGenerator to create a transformation that rescales the images by 255 and then applies a random zoom of up to 50%. Then use the .flow_from_directory method to apply the above transformation to the images in our training set. Make sure you indicate the batch size, the path to the directory of the training images, the target size for the images, and to shuffle the images.

# %%
image_gen = ImageDataGenerator(rescale=1./255, zoom_range = 0.5)

train_data_gen = image_gen.flow_from_directory(batch_size=BATCH_SIZE,
                                               directory=train_dir,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 2935 images belonging to 5 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# In the cell below, use ImageDataGenerator to create a transformation that rescales the images by 255 and that applies:
#
# * random 45 degree rotation
# * random zoom of up to 50%
# * random horizontal flip
# * width shift of 0.15
# * height shift of 0.15
# Then use the .flow_from_directory method to apply the above transformation to the images in our training set. Make sure you indicate the batch size, the path to the directory of the training images, the target size for the images, to shuffle the images, and to set the class mode to sparse.

# %%
image_gen = ImageDataGenerator(rescale=1./255, rotation_range = 45, zoom_range = 0.5, horizontal_flip= True, width_shift_range = 0.15, height_shift_range= 0.15)

train_data_gen = image_gen.flow_from_directory(batch_size=BATCH_SIZE,
                                               directory=train_dir,
                                               shuffle=True,
                                               class_mode = 'sparse',
                                               target_size=(IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 2935 images belonging to 5 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ### Create a Data Generator for the Validation Set
# Generally, we only apply data augmentation to our training examples. So, in the cell below, use ImageDataGenerator to create a transformation that only rescales the images by 255. Then use the .flow_from_directory method to apply the above transformation to the images in our validation set. Make sure you indicate the batch size, the path to the directory of the validation images, the target size for the images, and to set the class mode to sparse. Remember that it is not necessary to shuffle the images in the validation set.

# %%
image_gen = ImageDataGenerator(rescale=1./255, rotation_range = 45, zoom_range = 0.5, horizontal_flip= True, width_shift_range = 0.15, height_shift_range= 0.15)

val_data_gen = image_gen.flow_from_directory(batch_size=BATCH_SIZE,
                                               directory=val_dir,
                                               shuffle=False,
                                             class_mode='sparse',
                                               target_size=(IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 735 images belonging to 5 classes.

# %% [markdown]
# ### Create the CNN
# In the cell below, create a convolutional neural network that consists of 3 convolution blocks. Each convolutional block contains a Conv2D layer followed by a max pool layer. The first convolutional block should have 16 filters, the second one should have 32 filters, and the third one should have 64 filters. All convolutional filters should be 3 x 3. All max pool layers should have a pool_size of (2, 2).
#
# After the 3 convolutional blocks you should have a flatten layer followed by a fully connected layer with 512 units. The CNN should output class probabilities based on 5 classes which is done by the softmax activation function. All other layers should use a relu activation function. You should also add Dropout layers with a probability of 20%, where appropriate.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(5)
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               9470464
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 9,496,613
# Trainable params: 9,496,613
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model
# In the cell below, compile your model using the ADAM optimizer, the sparse cross entropy function as a loss function. We would also like to look at training and validation accuracy on each epoch as we train our network, so make sure you also pass the metrics argument.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Train the Model
# In the cell below, train your model using the fit_generator function instead of the usual fit function. We have to use the fit_generator function because we are using the ImageDataGenerator class to generate batches of training and validation data for our model. Train the model for 80 epochs and make sure you use the proper parameters in the fit_generator function.

# %%
EPOCHS = 80
history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(train_data_gen.n / float(BATCH_SIZE))),
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(val_data_gen.n / float(BATCH_SIZE)))
)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 36s 1s/step - loss: 2.1980 - accuracy: 0.2450 - val_loss: 1.4768 - val_accuracy: 0.3687
# Epoch 2/80
# 30/30 [==============================] - 37s 1s/step - loss: 1.2960 - accuracy: 0.4293 - val_loss: 1.2212 - val_accuracy: 0.4993
# Epoch 3/80
# 30/30 [==============================] - 54s 2s/step - loss: 1.1244 - accuracy: 0.5496 - val_loss: 1.0936 - val_accuracy: 0.5469
# Epoch 4/80
# 30/30 [==============================] - 50s 2s/step - loss: 1.0750 - accuracy: 0.5724 - val_loss: 1.0599 - val_accuracy: 0.5728
# Epoch 5/80
# 30/30 [==============================] - 47s 2s/step - loss: 1.0315 - accuracy: 0.5888 - val_loss: 1.0486 - val_accuracy: 0.5837
# Epoch 6/80
# 30/30 [==============================] - 48s 2s/step - loss: 0.9796 - accuracy: 0.6106 - val_loss: 1.0103 - val_accuracy: 0.6163
# Epoch 7/80
# 30/30 [==============================] - 51s 2s/step - loss: 0.9419 - accuracy: 0.6228 - val_loss: 0.9578 - val_accuracy: 0.6381
# Epoch 8/80
# 30/30 [==============================] - 45s 2s/step - loss: 0.9105 - accuracy: 0.6436 - val_loss: 0.9072 - val_accuracy: 0.6395
# Epoch 9/80
# 30/30 [==============================] - 65s 2s/step - loss: 0.8962 - accuracy: 0.6433 - val_loss: 0.9268 - val_accuracy: 0.6476
# Epoch 10/80
# 30/30 [==============================] - 47s 2s/step - loss: 0.8698 - accuracy: 0.6606 - val_loss: 0.9090 - val_accuracy: 0.6653
# Epoch 11/80
# 30/30 [==============================] - 52s 2s/step - loss: 0.8602 - accuracy: 0.6695 - val_loss: 0.9277 - val_accuracy: 0.6653
# Epoch 12/80
# 30/30 [==============================] - 57s 2s/step - loss: 0.8223 - accuracy: 0.6862 - val_loss: 0.9184 - val_accuracy: 0.6544
# Epoch 13/80
# 30/30 [==============================] - 51s 2s/step - loss: 0.8319 - accuracy: 0.6709 - val_loss: 0.8784 - val_accuracy: 0.6599
# Epoch 14/80
# 30/30 [==============================] - 50s 2s/step - loss: 0.7968 - accuracy: 0.6957 - val_loss: 0.8447 - val_accuracy: 0.6748
# Epoch 15/80
# 30/30 [==============================] - 47s 2s/step - loss: 0.7848 - accuracy: 0.6896 - val_loss: 0.8539 - val_accuracy: 0.6639
# Epoch 16/80
# 30/30 [==============================] - 42s 1s/step - loss: 0.7984 - accuracy: 0.6934 - val_loss: 0.8376 - val_accuracy: 0.6816
# Epoch 17/80
# 30/30 [==============================] - 48s 2s/step - loss: 0.7648 - accuracy: 0.7077 - val_loss: 0.8810 - val_accuracy: 0.6776
# Epoch 18/80
# 30/30 [==============================] - 48s 2s/step - loss: 0.7756 - accuracy: 0.7002 - val_loss: 0.8361 - val_accuracy: 0.6707
# Epoch 19/80
# 30/30 [==============================] - 51s 2s/step - loss: 0.7417 - accuracy: 0.7046 - val_loss: 0.8281 - val_accuracy: 0.6857
# Epoch 20/80
# 30/30 [==============================] - 51s 2s/step - loss: 0.7317 - accuracy: 0.7210 - val_loss: 0.8087 - val_accuracy: 0.6803
# Epoch 21/80
# 30/30 [==============================] - 50s 2s/step - loss: 0.7404 - accuracy: 0.7148 - val_loss: 0.8367 - val_accuracy: 0.6694
# Epoch 22/80
# 30/30 [==============================] - 48s 2s/step - loss: 0.7240 - accuracy: 0.7148 - val_loss: 0.8323 - val_accuracy: 0.6762
# Epoch 23/80
# 30/30 [==============================] - 50s 2s/step - loss: 0.7150 - accuracy: 0.7203 - val_loss: 0.8174 - val_accuracy: 0.6776
# Epoch 24/80
# 30/30 [==============================] - 49s 2s/step - loss: 0.6956 - accuracy: 0.7274 - val_loss: 0.8403 - val_accuracy: 0.6939
# Epoch 25/80
# 30/30 [==============================] - 49s 2s/step - loss: 0.6885 - accuracy: 0.7356 - val_loss: 0.8576 - val_accuracy: 0.6844
# Epoch 26/80
# 30/30 [==============================] - 50s 2s/step - loss: 0.6847 - accuracy: 0.7390 - val_loss: 0.7843 - val_accuracy: 0.6816
# Epoch 27/80
# 30/30 [==============================] - 53s 2s/step - loss: 0.6963 - accuracy: 0.7288 - val_loss: 0.7695 - val_accuracy: 0.7034
# Epoch 28/80
# 30/30 [==============================] - 55s 2s/step - loss: 0.6641 - accuracy: 0.7441 - val_loss: 0.7834 - val_accuracy: 0.7102
# Epoch 29/80
# 30/30 [==============================] - 57s 2s/step - loss: 0.6475 - accuracy: 0.7486 - val_loss: 0.8123 - val_accuracy: 0.7088
# Epoch 30/80
# 30/30 [==============================] - 48s 2s/step - loss: 0.6525 - accuracy: 0.7468 - val_loss: 0.7546 - val_accuracy: 0.7007
# Epoch 31/80
# 30/30 [==============================] - 49s 2s/step - loss: 0.6496 - accuracy: 0.7472 - val_loss: 0.7974 - val_accuracy: 0.6857
# Epoch 32/80
# 30/30 [==============================] - 49s 2s/step - loss: 0.6445 - accuracy: 0.7479 - val_loss: 0.7657 - val_accuracy: 0.6952
# Epoch 33/80
# 30/30 [==============================] - 52s 2s/step - loss: 0.6192 - accuracy: 0.7547 - val_loss: 0.7798 - val_accuracy: 0.6844
# Epoch 34/80
# 30/30 [==============================] - 53s 2s/step - loss: 0.6518 - accuracy: 0.7445 - val_loss: 0.8420 - val_accuracy: 0.6857
# Epoch 35/80
# 30/30 [==============================] - 51s 2s/step - loss: 0.6225 - accuracy: 0.7588 - val_loss: 0.7525 - val_accuracy: 0.7170
# Epoch 36/80
# 30/30 [==============================] - 50s 2s/step - loss: 0.6062 - accuracy: 0.7615 - val_loss: 0.7616 - val_accuracy: 0.7102
# Epoch 37/80
# 30/30 [==============================] - 48s 2s/step - loss: 0.6068 - accuracy: 0.7659 - val_loss: 0.7360 - val_accuracy: 0.7184
# Epoch 38/80
# 30/30 [==============================] - 52s 2s/step - loss: 0.5921 - accuracy: 0.7717 - val_loss: 0.8841 - val_accuracy: 0.6912
# Epoch 39/80
# 30/30 [==============================] - 48s 2s/step - loss: 0.6082 - accuracy: 0.7710 - val_loss: 0.7366 - val_accuracy: 0.7347
# Epoch 40/80
# 30/30 [==============================] - 49s 2s/step - loss: 0.5906 - accuracy: 0.7670 - val_loss: 0.7614 - val_accuracy: 0.7224
# Epoch 41/80
# 30/30 [==============================] - 43s 1s/step - loss: 0.5916 - accuracy: 0.7700 - val_loss: 0.7053 - val_accuracy: 0.7252
# Epoch 42/80
# 30/30 [==============================] - 42s 1s/step - loss: 0.5681 - accuracy: 0.7782 - val_loss: 0.7685 - val_accuracy: 0.7265
# Epoch 43/80
# 30/30 [==============================] - 45s 2s/step - loss: 0.5560 - accuracy: 0.7826 - val_loss: 0.7226 - val_accuracy: 0.7184
# Epoch 44/80
# 30/30 [==============================] - 52s 2s/step - loss: 0.5538 - accuracy: 0.7816 - val_loss: 0.7371 - val_accuracy: 0.7156
# Epoch 45/80
# 30/30 [==============================] - 51s 2s/step - loss: 0.5455 - accuracy: 0.7932 - val_loss: 0.7672 - val_accuracy: 0.7238
# Epoch 46/80
# 30/30 [==============================] - 53s 2s/step - loss: 0.5609 - accuracy: 0.7843 - val_loss: 0.7500 - val_accuracy: 0.7211
# Epoch 47/80
# 30/30 [==============================] - 50s 2s/step - loss: 0.5335 - accuracy: 0.7949 - val_loss: 0.7421 - val_accuracy: 0.7088
# Epoch 48/80
# 30/30 [==============================] - 49s 2s/step - loss: 0.5452 - accuracy: 0.7877 - val_loss: 0.7522 - val_accuracy: 0.7048
# Epoch 49/80
# 30/30 [==============================] - 44s 1s/step - loss: 0.5298 - accuracy: 0.7945 - val_loss: 0.7023 - val_accuracy: 0.7429
# Epoch 50/80
# 30/30 [==============================] - 42s 1s/step - loss: 0.5294 - accuracy: 0.7949 - val_loss: 0.7202 - val_accuracy: 0.7265
# Epoch 51/80
# 30/30 [==============================] - 41s 1s/step - loss: 0.5328 - accuracy: 0.7997 - val_loss: 0.7263 - val_accuracy: 0.7238
# Epoch 52/80
# 30/30 [==============================] - 50s 2s/step - loss: 0.5199 - accuracy: 0.8024 - val_loss: 0.7207 - val_accuracy: 0.7252
# Epoch 53/80
# 30/30 [==============================] - 47s 2s/step - loss: 0.5263 - accuracy: 0.8000 - val_loss: 0.7816 - val_accuracy: 0.7034
# Epoch 54/80
# 30/30 [==============================] - 45s 2s/step - loss: 0.5123 - accuracy: 0.7993 - val_loss: 0.7336 - val_accuracy: 0.7333
# Epoch 55/80
# 30/30 [==============================] - 42s 1s/step - loss: 0.4933 - accuracy: 0.8075 - val_loss: 0.7838 - val_accuracy: 0.7102
# Epoch 56/80
# 30/30 [==============================] - 51s 2s/step - loss: 0.4922 - accuracy: 0.8078 - val_loss: 0.7059 - val_accuracy: 0.7374
# Epoch 57/80
# 30/30 [==============================] - 51s 2s/step - loss: 0.4930 - accuracy: 0.8078 - val_loss: 0.7572 - val_accuracy: 0.7265
# Epoch 58/80
# 30/30 [==============================] - 49s 2s/step - loss: 0.5035 - accuracy: 0.8044 - val_loss: 0.7095 - val_accuracy: 0.7156
# Epoch 59/80
# 30/30 [==============================] - 44s 1s/step - loss: 0.4915 - accuracy: 0.8031 - val_loss: 0.7276 - val_accuracy: 0.7252
# Epoch 60/80
# 30/30 [==============================] - 41s 1s/step - loss: 0.4741 - accuracy: 0.8170 - val_loss: 0.7501 - val_accuracy: 0.7143
# Epoch 61/80
# 30/30 [==============================] - 48s 2s/step - loss: 0.4663 - accuracy: 0.8194 - val_loss: 0.7327 - val_accuracy: 0.7102
# Epoch 62/80
# 30/30 [==============================] - 42s 1s/step - loss: 0.4581 - accuracy: 0.8269 - val_loss: 0.7520 - val_accuracy: 0.7374
# Epoch 63/80
# 30/30 [==============================] - 44s 1s/step - loss: 0.4622 - accuracy: 0.8208 - val_loss: 0.7610 - val_accuracy: 0.7374
# Epoch 64/80
# 30/30 [==============================] - 41s 1s/step - loss: 0.4706 - accuracy: 0.8164 - val_loss: 0.6911 - val_accuracy: 0.7415
# Epoch 65/80
# 30/30 [==============================] - 43s 1s/step - loss: 0.4434 - accuracy: 0.8310 - val_loss: 0.7883 - val_accuracy: 0.7333
# Epoch 66/80
# 30/30 [==============================] - 43s 1s/step - loss: 0.4570 - accuracy: 0.8293 - val_loss: 0.6856 - val_accuracy: 0.7333
# Epoch 67/80
# 30/30 [==============================] - 44s 1s/step - loss: 0.4554 - accuracy: 0.8276 - val_loss: 0.7030 - val_accuracy: 0.7279
# Epoch 68/80
# 30/30 [==============================] - 58s 2s/step - loss: 0.4393 - accuracy: 0.8317 - val_loss: 0.7092 - val_accuracy: 0.7483
# Epoch 69/80
# 30/30 [==============================] - 53s 2s/step - loss: 0.4384 - accuracy: 0.8283 - val_loss: 0.7435 - val_accuracy: 0.7306
# Epoch 70/80
# 30/30 [==============================] - 48s 2s/step - loss: 0.4390 - accuracy: 0.8317 - val_loss: 0.7471 - val_accuracy: 0.7170
# Epoch 71/80
# 30/30 [==============================] - 58s 2s/step - loss: 0.4510 - accuracy: 0.8232 - val_loss: 0.7435 - val_accuracy: 0.7401
# Epoch 72/80
# 30/30 [==============================] - 59s 2s/step - loss: 0.4084 - accuracy: 0.8375 - val_loss: 0.7752 - val_accuracy: 0.7279
# Epoch 73/80
# 30/30 [==============================] - 52s 2s/step - loss: 0.4235 - accuracy: 0.8385 - val_loss: 0.6898 - val_accuracy: 0.7633
# Epoch 74/80
# 30/30 [==============================] - 50s 2s/step - loss: 0.4282 - accuracy: 0.8388 - val_loss: 0.7173 - val_accuracy: 0.7374
# Epoch 75/80
# 30/30 [==============================] - 52s 2s/step - loss: 0.4159 - accuracy: 0.8457 - val_loss: 0.7508 - val_accuracy: 0.7524
# Epoch 76/80
# 30/30 [==============================] - 50s 2s/step - loss: 0.3992 - accuracy: 0.8535 - val_loss: 0.7978 - val_accuracy: 0.7374
# Epoch 77/80
# 30/30 [==============================] - 52s 2s/step - loss: 0.4313 - accuracy: 0.8395 - val_loss: 0.7217 - val_accuracy: 0.7456
# Epoch 78/80
# 30/30 [==============================] - 56s 2s/step - loss: 0.4017 - accuracy: 0.8443 - val_loss: 0.8348 - val_accuracy: 0.7197
# Epoch 79/80
# 30/30 [==============================] - 52s 2s/step - loss: 0.4127 - accuracy: 0.8491 - val_loss: 0.7711 - val_accuracy: 0.7197
# Epoch 80/80
# 30/30 [==============================] - 58s 2s/step - loss: 0.4249 - accuracy: 0.8450 - val_loss: 0.7589 - val_accuracy: 0.7388

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Summary
# In this lesson we learned how Convolutional Neural Networks work with color images and saw various techniques that we can use to avoid overfitting . The main key points of this lesson are:
#
# CNNs with RGB Images of Different Sizes:
#
# Resizing: When working with images of different sizes, you must resize all the images to the same size so that they can be fed into a CNN.
# Color Images: Computers interpret color images as 3D arrays.
# RGB Image: Color image composed of 3 color channels: Red, Green, and Blue.
# Convolutions: When working with RGB images we convolve each color channel with its own convolutional filter. Convolutions on each color channel are performed in the same way as with grayscale images, i.e. by performing element-wise multiplication of the convolutional filter (kernel) and a section of the input array. The result of each convolution is added up together with a bias value to get the convoluted output.
# Max Pooling: When working with RGB images we perform max pooling on each color channel using the same window size and stride. Max pooling on each color channel is performed in the same way as with grayscale images, i.e. by selecting the max value in each window.
# Validation Set: We use a validation set to check how the model is doing during the training phase. Validation sets can be used to perform Early Stopping to prevent overfitting and can also be used to help us compare different models and choose the best one.
# Methods to Prevent Overfitting:
#
# Early Stopping: In this method, we track the loss on the validation set during the training phase and use it to determine when to stop training such that the model is accurate but not overfitting.
# Image Augmentation: Artificially boosting the number of images in our training set by applying random image transformations to the existing images in the training set.
# Dropout: Removing a random selection of a fixed number of neurons in a neural network during training.
# You also created and trained a Convolutional Neural Network to classify images of Dogs and Cats with and without Image Augmentation and Dropout. You were able to see that Image Augmentation and Dropout greatly reduces overfitting and improves accuracy. As an exercise, you were able to apply everything you learned in this lesson to create your own CNN to classify images of flowers.
